# %%
#sometimes we'll want to specify a later line if there is extra meta information at the top of the file
#df_cancer = pd.read_csv('data.csv',header=2) #took the 3rd row as column
#df_cancer.head()

# If columns labels are not included in your file, you can use header=None to prevent your first line of 
# data from being misinterpreted as column labels.
# df_cancer = pd.read_csv('data.csv',header=None) #took the 3rd row as column
# df_cancer.head()

# If you want to tell pandas that there was a header line that you are replacing, 
# you can specify the row of that line like this.
# labels = ['id', 'name', 'attendance', 'hw', 'test1', 'project1', 'test2', 'project2', 'final']
# df = pd.read_csv('student_scores.csv', header=0, names=labels)
# df.head()

# df = pd.read_csv('data.csv', index_col=['id'])
# df.head()

# What is this Unnamed:0? to_csv() will store our index unless we tell it not to. 
# To make it ignore the index, we have to provide the parameter index=False
# df = df_cancer.to_csv('cancer_data.csv', index=False)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_cancer = pd.read_csv('../data/data.csv')
df_cancer.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
for k,v in enumerate(df_cancer.columns):
    print(k,'        ',v)
# Out:
# 0          id
# 1          diagnosis
# 2          radius_mean
# 3          texture_mean
# 4          perimeter_mean
# 5          area_mean
# 6          smoothness_mean
# 7          compactness_mean
# 8          concavity_mean
# 9          concave points_mean
# 10          symmetry_mean
# 11          fractal_dimension_mean
# 12          radius_se
# 13          texture_se
# 14          perimeter_se
# 15          area_se
# 16          smoothness_se
# 17          compactness_se
# 18          concavity_se
# 19          concave points_se
# 20          symmetry_se
# 21          fractal_dimension_se
# 22          radius_worst
# 23          texture_worst
# 24          perimeter_worst
# 25          area_worst
# 26          smoothness_worst
# 27          compactness_worst
# 28          concavity_worst
# 29          concave points_worst
# 30          symmetry_worst
# 31          fractal_dimension_worst
# 32          Unnamed: 32

# %%
df_cancer.shape
# Out:
# (569, 33)

# %%
df_cancer.dtypes
# Out:
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# ...

# %%
# object is actually a string in python
# type(df_cancer['diagnosis']) --> object
type(df_cancer['diagnosis'][0]) #further analysis --> str
# Out:
# str

# %%
df_cancer.nunique()
# Out:
# id                         569
# diagnosis                    2
# radius_mean                456
# texture_mean               479
# perimeter_mean             522
# area_mean                  539
# smoothness_mean            474
# compactness_mean           537
# concavity_mean             537
# concave points_mean        542
# symmetry_mean              432
# fractal_dimension_mean     499
# radius_se                  540
# texture_se                 519
# perimeter_se               533
# area_se                    528
# smoothness_se              547
# compactness_se             541
# concavity_se               533
# concave points_se          507
# symmetry_se                498
# fractal_dimension_se       545
# radius_worst               457
# texture_worst              511
# perimeter_worst            514
# area_worst                 544
# smoothness_worst           411
# compactness_worst          529
# concavity_worst            539
# concave points_worst       492
# ...

# %%
df_cancer.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df_cancer.loc[:,'radius_mean':'area_mean'].head(2)
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean
# 0        17.99         10.38           122.8     1001.0
# 1        20.57         17.77           132.9     1326.0

# %%
df_cancer.iloc[:,2:6].head(2)
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean
# 0        17.99         10.38           122.8     1001.0
# 1        20.57         17.77           132.9     1326.0

# %%
df_cancer.iloc[:,np.r_[0,1,12:22]].head(2)
# Out:
#        id diagnosis  radius_se  texture_se  perimeter_se  area_se  \
# 0  842302         M     1.0950      0.9053         8.589   153.40
# 1  842517         M     0.5435      0.7339         3.398    74.08
#
#    smoothness_se  compactness_se  concavity_se  concave points_se  \
# 0       0.006399         0.04904       0.05373            0.01587
# 1       0.005225         0.01308       0.01860            0.01340
#
#    symmetry_se  fractal_dimension_se
# 0      0.03003              0.006193
# 1      0.01389              0.003532

# %%
df_cancer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
# id                         569 non-null int64
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# ...

# %%
sum(df_cancer.duplicated())
df_cancer.drop_duplicates(inplace=True)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
list(df_cancer.columns)[]
# Out:
# []

# %%
# l = ['abc_1','abc_2','def_1']
# new_l = []
# for list_item in l:
#     if 'abc' in list_item:
#         print('found')
#         new_l.append(list_item[4:])
#     else:
#         print('not found')

# new_l
# abc = 'defghij'
# abc[:4]

new_labels = []
#print(df_cancer.columns)
for col in df_cancer.columns:
    if '_mean' in col:
        new_labels.append(col[:-5])
    else:
        new_labels.append(col)
        
df_cancer.columns = new_labels
df_cancer.columns
# Out:
# Index(['id', 'diagnosis', 'radius', 'texture', 'perimeter', 'area',
#        'smoothness', 'compactness', 'concavity', 'concave points', 'symmetry',
#        'fractal_dimension', 'radius_se', 'texture_se', 'perimeter_se',
#        'area_se', 'smoothness_se', 'compactness_se', 'concavity_se',
#        'concave points_se', 'symmetry_se', 'fractal_dimension_se',
#        'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst',
#        'smoothness_worst', 'compactness_worst', 'concavity_worst',
#        'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst',
#        'Unnamed: 32'],
#       dtype='object')

# %%
df_cancer.to_csv('cancer_data_edited.csv', index=False)

# %%
sns.pairplot(df_cancer)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-116-ebc23349318a> in <module>
# ----> 1 sns.pairplot(df_cancer)
#
# /Applications/Utilities/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2105     if grid.square_grid:
#    2106         if diag_kind == "hist":
# -> 2107             grid.map_diag(plt.hist, **diag_kws)
#    2108         elif diag_kind == "kde":
#    2109             diag_kws.setdefault("shade", True)
#
# /Applications/Utilities/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in map_diag(self, func, **kwargs)
#    1397                     color = fixed_color
#    1398
# -> 1399                 func(data_k, label=label_k, color=color, **kwargs)
#    1400
# ...

# %%
df_cancer.plot(x='compactness_se',y='concavity_se',kind='scatter')

# %%
df_cancer['concavity_se'].plot(kind='box')
#sns.boxplot(df_cancer['concavity_se'])

# %%
df_diag_m = df_cancer[df_cancer['diagnosis']=='M']
df_diag_b = df_cancer[df_cancer['diagnosis']=='B']
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
df_diag_b['area_mean'].describe()
df_diag_m['area_mean'].describe()
# Out:
# count     212.000000
# mean      978.376415
# std       367.937978
# min       361.600000
# 25%       705.300000
# 50%       932.000000
# 75%      1203.750000
# max      2501.000000
# Name: area_mean, dtype: float64

# %%
'The mean on malignant tumors is {0:.4f} while that of benign tumors is {1:.4f}'.format(df_diag_m['area_mean'].mean(),df_diag_b['area_mean'].mean())
# Out:
# 'The mean on malignant tumors is 978.3764 while that of benign tumors is 462.7902'

# %%
fig,ax = plt.subplots(figsize=(8,8))
ax.hist(df_diag_b['area_mean'],alpha=0.5,label='benign')
ax.hist(df_diag_m['area_mean'],alpha=0.5,label='malignant')
ax.set_title('Distribution of malignant and benign tumors in area_mean')
ax.set_xlabel('Area')
ax.set_ylabel('Count')
ax.legend(loc='upper right')
plt.show()

# mean_area of malignant tumors is generally larger than compared to bening tumor

# %%
labels = ['age','workclass','fnlwgt','education','education-num','marital-status','occupation','relationship','race','sex',
'capital-gain','capital-loss','hours-per-week','native-country']
df_adult = pd.read_csv('adult.data',header=None,names=labels,index_col=False)

# %%
df_adult.shape[0] # rows
# Out:
# 32561

# %%
df_adult.shape[1] # columns
# Out:
# 14

# %%
df_adult.info()
# 32561 non-null values in a particular column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 14 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education-num     32561 non-null int64
# marital-status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital-gain      32561 non-null int64
# capital-loss      32561 non-null int64
# hours-per-week    32561 non-null int64
# native-country    32561 non-null object
# dtypes: int64(6), object(8)
# memory usage: 3.5+ MB

# %%
df_adult.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# dtype: object

# %%
df_adult.columns[] # columns with missing values
# Out:
# Index([], dtype='object')

# %%
df_adult['education'].nunique()
# Out:
# 16

# %%
np.mean(df_adult['age'])
# Out:
# 38.58164675532078

# %%
np.percentile(df_adult['hours-per-week'],75)
# Out:
# 45.0

# %%
df_adult['hours-per-week'].describe()
# Out:
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000
# Name: hours-per-week, dtype: float64

# %%
# Count the number of null values in each column
df_adult.isna().sum()
# Count the number of null values in the whole dataframe
df_adult.isnull().sum().sum()
# Out:
# 0

# %%
sum(df_adult.duplicated())
df_adult.drop_duplicates(inplace=True)
# Out:
# 0

# %%
# use means to fill in missing values
df_adult['capital-gain'].fillna(np.mean(df_adult['capital-gain']),inplace=True)
# confirm your correction with info()
df_adult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32536 entries, 0 to 32560
# Data columns (total 14 columns):
# age               32536 non-null int64
# workclass         32536 non-null object
# fnlwgt            32536 non-null int64
# education         32536 non-null object
# education-num     32536 non-null int64
# marital-status    32536 non-null object
# occupation        32536 non-null object
# relationship      32536 non-null object
# race              32536 non-null object
# sex               32536 non-null object
# capital-gain      32536 non-null int64
# capital-loss      32536 non-null int64
# hours-per-week    32536 non-null int64
# native-country    32536 non-null object
# dtypes: int64(6), object(8)
# memory usage: 3.7+ MB

# %%
df_adult.hist(figsize=(7,7));

# %%
df_adult['age'].hist()

# %%
df_adult['age'].plot(kind='hist')

# %%
df_adult['education'].value_counts().plot(kind='bar')

# %%
df_adult['education'].value_counts().plot(kind='pie',figsize=(8,8))

# %%
sns.pairplot(df_adult)
